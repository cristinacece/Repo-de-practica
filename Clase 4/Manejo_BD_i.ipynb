# %% [markdown]
# <a href="https://colab.research.google.com/github/cristinacece/Repo-de-practica/blob/main/Clase%204/Manejo_BD_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manejo de bases de datos para las ciencias sociales I
#
# - [Introdución](#intro)
#     - [Importar pandas](#impa)
#     - [El Objeto DataFrame](#objdf)
# - [Creando Dataframes](#crea)
# - [Leyendo Dataframes](#readi)
# - [Desafíos comunes con archivos de datos](#desafio)
# - [Trabajando con datos](#trabajando)
#     - [Exploración inicial](#exploracion)
#     - [Cómo seleccionar datos](#select)
#     - [Filtrando información](#filter)

# %% [markdown]
# <a class="anchor" id="intro"></a>
# ## Introducción
#
# _Previo: Tipos de datos._
#
# Al 2025, Python tiene una serie de librerías que manejan bases de datos tabulares <sup>1</sup>.
#
# [Pandas](https://pandas.pydata.org/docs/getting_started/index.html) es la librería más popular de Python para realizar análisis de datos. Esta se especializa en trabajar con ciertos tipos de datos. Los más importantes son:
#
# - Data tabular, como los dataframes (o cualquier base de datos estructurada que tengamos).
# - Series
# - Series de tiempo
#
# Los objetos de Pandas más importantes son 2:
# - Series
# - Dataframes (nuestro enfoque principal).
#
# <sup>1</sup> Recientemente, la discusión ha virado a mejores métodos para tratar big data. Paquetes como dask, y tipos de archivos binarios como parquet, son un punto inicial. Lo importante es lo siguiente: Son extensiones de Pandas! :)

# %% [markdown]
# Esta librería es un _must_ en el aprendizaje del análisis de datos, machine learning, etc por una serie de motivos:
# - Se integra perfectamente con librerías como scikit-learn (machine learning), matplotlib, seaborn y altair (visualización de datos), statsmodels (modelos estadísticos listos para usar), análisis de texto, análisis espacial (geopandas, etc).
#
# - La gran parte de la comunidad que hace data analysis, y que se apoya mediante foros y demás, usa Pandas.
# - Pandas es muy amplio y tiene muchas funcionalidades.

# %% [markdown]
# <a class="anchor" id="impa"></a>
#
# ### 1. Importar pandas

# %%
import pandas as pd

# %% [markdown]
# <a class="anchor" id="objdf"></a>
#
# ### 2. El objeto dataframe
#
# - Casi siempre trabajaremos con dataframes.
#
# Pero qué es un dataframe?
#
#
# - Es el **objeto** principal de pandas, el cual representa una estructura de datos de dos dimensiones: filas y columnas.
# - Cada fila es una observación o registro;  cada columna, una variable, atributo, _feature_, etc.
# - Hay un sólo valor por celda.
# - El dataframe sirve para representar `datos tabulares`.
#
#
# Adicionalmente, todo dataframe tiene un **índice**, que funge como identificador único de cada fila.
# Las columnas no necesitan ello, porque por regla, los nombres ya son su identificador único. Por ello, no se acepta nombres repetidos de columna.
#
# 2 maneras de usar dataframes: crearlo por nosotros mismos ó leer datos.

# %%
x = 1
df['mes'] # así nos referimos de manera vectorial a los datos de esa columna

# %% [markdown]
# <img src="https://github.com/ccsuehara/python_para_las_ccss/blob/main/img/db_example.jpeg?raw=1" width="800">
#
#
#
# <br>
# </br>

# %%
## SERIES: son vectores de datos. Una sábana de datos como la de arriba es un data frame.
## Un data frame es un conjunto de celdas juntas.
## También existe series individuales --> este es el primer objeto sobre el que se basa panda.
s1 = pd.Series([1,2,3,4], name = 'numeros')
type(s1)
# Out:
# pandas.core.series.Series

# %%
nombres_columnas = ['rural', 'pobreza', 'num_ccpp_urbano',
                    'desnutricion_cronica',
                    'centros_rural', 'es_juntos']

# %%
obs1 = [True, 40, 1, 50, 60, True]
obs2 = [True, 55, 2, 30, 55, True]
obs3 = [False, 25, 3, 40, 40, True]

obs4 = [True, 30, 2, 25, 55, False]

#así, nuestra data termina siendo una lista de lista:

data = [obs1, obs2, obs3, obs4]

# %%
ejemplo1 = pd.DataFrame(data = data, columns = nombres_columnas)
ejemplo1
# Out:
#    rural  pobreza  num_ccpp_urbano  desnutricion_cronica  centros_rural  \
# 0   True       40                1                    50             60
# 1   True       55                2                    30             55
# 2  False       25                3                    40             40
# 3   True       30                2                    25             55
#
#    es_juntos
# 0       True
# 1       True
# 2       True
# 3      False

# %%
c1 = [1, 2, 3, 4]
c2 = [True, False, True, True]

df = pd.DataFrame()
df['id'] = c1
df['pertenece'] = c2

# %%
df
# Out:
#    id  pertenece
# 0   1       True
# 1   2      False
# 2   3       True
# 3   4       True

# %%
df_= pd.DataFrame({'id' : c1, 'pertenece': c2})
df_
# Out:
#    id  pertenece
# 0   1       True
# 1   2      False
# 2   3       True
# 3   4       True

# %%
## DataFrame es un objeto compuesto por varias columnas o filas
## en las notas de programación orientada a objetos (OOP) esto se llama composición

# %% [markdown]
# <a class="anchor" id="crea"></a>
#
# ####  Una forma simple de crear dataframes:

# %% [markdown]
# - Por filas

# %%
nombres_columnas = ['rural', 'pobreza', 'num_ccpp_urbano',
                    'desnutricion_cronica',
                    'centros_rural', 'es_juntos']

obs1 = [True, 40, 1, 50, 60, True]
obs2 = [True, 55, 2, 30, 55, True]
obs3 = [False, 25, 3, 40, 40, True]

obs4 = [True, 30, 2, 25, 55, False]

data = [obs1, obs2, obs3, obs4]

#ejemplo_df = pd.DataFrame(data = data, columns = nombres_columnas)

ejemplo_df  = pd.DataFrame(data = data, columns = nombres_columnas)


ejemplo_df

# %%
pd.DataFrame()

# %% [markdown]
# - Por columnas

# %%
# Ejemplo cuna más de anterior clase
df = pd.DataFrame()

df['rural'] = [True, True, False, True, False]
df['pobreza'] = [40, 55, 25, 60, 30]
df['rnum_ccpp_urbano'] =[1,2,3,4,5]
df['rdesnutricion_cronica'] = [50,30,40,20,45]
df['rcentros_rural'] = [60,55,40,50,20]
df['res_juntos'] = [True, True, True, True, True]


## df['cuna_o_no'] = [False, True, True, False, True]
df

# %%
type(pd.DataFrame())

# %% [markdown]
# ### Vectorización:
# La vectorización se define como aplicar una operación sobre el conjunto de elementos de un vector, en lugar de hacerlo sobre cada elemento de forma individual.
# Pandas integra dicha vectorización tal que las operaciones se realizan más rápida, fácil y eficientemente.

# %%
mivar = 5

# %%
# Ejemplo de vectorización:
## Nótese: Aquí creamos un dataframe con un diccionario, donde las llaves son los nombres de las columnas y
#  los valores son listas con los valores de cada columna.
df = pd.DataFrame({'vec': [1, 2, 3, 4, 5],
                   'non_vec': [1, 2, 3, 4, 5]})

# # No vectorizado: Se utiliza un bucle para realizar la operación.
for i in range(len(df)):
    df.at[i, 'non_vec'] += 10

# print(df)
# # Vewctorizado: Se llama al nombre de la variable como si fuera un vector.
df['vec'] = df['vec'] + 10

df

# %%
df = pd.DataFrame({'vec': [1, 2, 3, 4, 5],
                   'non_vec': [1, 2, 3, 4, 5]})
len(df)
# Out:
# 5

# %%
for i in range (len(df)):
  df.at[i, 'non_vec'] += 10

# %%
df['vec'] = df['vec'] + 10

df
# Out:
#    vec  non_vec
# 0   11       11
# 1   12       12
# 2   13       13
# 3   14       14
# 4   15       15

# %% [markdown]
# <a class="anchor" id="readi"></a>
#
# #### Leyendo la información:
# Los archivos que tenemos pueden estar en distintos formatos: dta, sav, json, csv, txt. Pandas puede leer cualquiera de dichos tipos de archivos.
# Lo importante es que en esencia, todos ellos representan datos **tabulares**, o datos que tienen
#
#
# | Método de pandas según file | Tipo de archivo        | Descripción                              |
# |------------------|------------------------|------------------------------------------|
# | `read_csv()`     | CSV                    | Lee archivos de valores separados por comas (CSV). |
# | `read_json()`    | JSON                   | Lee datos estructurados como JSON. |
# | `read_stata()`   | Stata                  | Lee archivos de datos en Stata.          |
# | `read_spss()`    | SPSS                   | Lee archivos de datos en SPSS.           |
# | `read_excel()`   | Excel (xls, xlsx)      | Lee archivos Excel.              |
# | `read_pickle()`  | Pickle                 | Lee objetos Python serializados almacenados en archivos Pickle. |
# | `read_parquet()` | Parquet                | Lee archivos Parquet.         |
# | `read_feather()` | Feather                | Lee archivos Feather.         |
# | `read_sql()`     | SQL Query / Database   | Lee de una base de datos usando una consulta SQL. |
# | `read_sas()`     | SAS                    | Lee archivos de datos de SAS.            |
# | `read_hdf()`     | HDF5                   | Lee archivos HDF5.            |
# | `read_orc()`     | ORC                    | Lee archivos ORC.             |
# | `read_fwf()`     | Fixed-Width Formatted  | Lee archivos de texto con ancho fijo.    |
#
# - Los métodos están organizados según importancia.
# - Hay otros métodos como `read_html`, `read_orc`, y `read_fwf`. Otros paquetes adicionales leen, por ejemplo, archivos .RData (R).

# %% [markdown]
# Hoy nos enfocaremos en la base de datos de postulantes de la Universidad Nacional de Ingeniería:
# https://www.datosabiertos.gob.pe/dataset/postulantes-al-concurso-de-admisi%C3%B3n-de-la-universidad-nacional-de-ingenier%C3%ADa-uni

# %%
## Leyendo los archivos.
locacion_datos = "aqui  coloca el string con la locación de tus datos"
locacion_datos = "/content/Datos_abiertos_admision_2021_1_2024_1.csv" # este es el mio
df = pd.read_csv(locacion_datos)

# %%
df
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# 2      0113 DANIEL ALOMIAS ROBLES         LIMA                   LIMA
# 3         SEBASTIAN SALAZAR BONDY         LIMA                   LIMA
# 4               TRILCE LOS OLIVOS         LIMA                   LIMA
# ...                           ...          ...                    ...
# 42511           BARTOLOME HERRERA         LIMA                   LIMA
# 42512             FE Y ALEGRIA 59       CALLAO  PROV CONST DEL CALLAO
# 42513                    CIENCIAS     AYACUCHO               HUAMANGA
# 42514                  SAN CARLOS         LIMA                   LIMA
# 42515             TRILCE SAN JUAN         LIMA                   LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 1                      HUARAZ         PERÚ                 2017
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# ...                       ...          ...                  ...
# 42511              SAN MIGUEL          NaN                 2019
# 42512              VENTANILLA          NaN                 2021
# 42513       SAN JUAN BAUTISTA          NaN                 2022
# 42514              LURIGANCHO          NaN                 2021
# 42515  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                            ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0                INGENIERÍA DE SISTEMAS          2021              1  ...
# 1      INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 2                   INGENIERÍA MECÁNICA          2021              1  ...
# 3                INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                          ARQUITECTURA          2021              1  ...
# ...                                 ...           ...            ...  ...
# 42511                  INGENIERÍA CIVIL          2023              1  ...
# 42512                  INGENIERÍA CIVIL          2023              1  ...
# 42513                      ARQUITECTURA          2023              1  ...
# 42514                      ARQUITECTURA          2023              1  ...
# 42515            INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0      SAN JUAN DE MIRAFLORES            2004            PERÚ
# 1                      HUARAZ            2001            PERÚ
# 2      SAN JUAN DE LURIGANCHO            2000            PERÚ
# 3                 SANTA ANITA            2002            PERÚ
# 4               INDEPENDENCIA            2004            PERÚ
# ...                       ...             ...             ...
# 42511                LA PERLA            2002            PERÚ
# 42512              VENTANILLA            2004            PERÚ
# 42513                AYACUCHO            2006            PERÚ
# 42514              LURIGANCHO            2004            PERÚ
# 42515  SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 1               ÁNCASH                 HUARAZ                  HUARAZ
# 2                 LIMA                   LIMA             JESÚS MARÍA
# 3                 LIMA                   LIMA                    LIMA
# 4                 LIMA                   LIMA                   COMAS
# ...                ...                    ...                     ...
# 42511           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42512           CALLAO  PROV CONST DEL CALLAO                  CALLAO
# 42513         AYACUCHO               HUAMANGA                AYACUCHO
# 42514             LIMA                   LIMA              MIRAFLORES
# 42515             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 1       FEMENINO       3.580      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# ...          ...         ...     ...
# 42511  MASCULINO       5.906      NO
# 42512   FEMENINO       2.621      NO
# 42513   FEMENINO       7.974      NO
# 42514   FEMENINO       9.477      NO
# 42515  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 1                                              ORDINARIO
# 2                                              ORDINARIO
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                              ORDINARIO
# ...                                                  ...
# 42511                                          ORDINARIO
# 42512                                          ORDINARIO
# 42513                                          ORDINARIO
# 42514                                          ORDINARIO
# 42515                                          ORDINARIO
#
# [42516 rows x 22 columns]

# %%
df.shape
# Out:
# (42516, 22)

# %%
df.info()
# sirve para ver los tipos de variables, series y columnas, también atributo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42516 entries, 0 to 42515
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IDHASH               42516 non-null  object
#  1   COLEGIO              42516 non-null  object
#  2   COLEGIO_DEPA         42290 non-null  object
#  3   COLEGIO_PROV         42288 non-null  object
#  4   COLEGIO_DIST         42288 non-null  object
#  5   COLEGIO_PAIS         18942 non-null  object
#  6   COLEGIO_ANIO_EGRESO  42516 non-null  int64
#  7   ESPECIALIDAD         42461 non-null  object
#  8   ANIO_POSTULA         42516 non-null  int64
#  9   CICLO_POSTULA        42516 non-null  int64
#  10  DOMICILIO_DEPA       42516 non-null  object
#  11  DOMICILIO_PROV       42516 non-null  object
#  12  DOMICILIO_DIST       42516 non-null  object
#  13  ANIO_NACIMIENTO      42516 non-null  int64
#  14  NACIMIENTO_PAIS      42516 non-null  object
#  15  NACIMIENTO_DEPA      42314 non-null  object
#  16  NACIMIENTO_PROV      42314 non-null  object
#  17  NACIMIENTO_DIST      42313 non-null  object
#  18  SEXO                 42516 non-null  object
#  19  CALIF_FINAL          42492 non-null  float64
#  20  INGRESO              42516 non-null  object
#  21  MODALIDAD            42516 non-null  object
# dtypes: float64(1), int64(4), object(17)
# memory usage: 7.1+ MB

# %%
df.describe()
# Out:
#        COLEGIO_ANIO_EGRESO  ANIO_POSTULA  CICLO_POSTULA  ANIO_NACIMIENTO  \
# count         42516.000000  42516.000000   42516.000000     42516.000000
# mean           2020.043301   2022.564352       1.313082      2003.665138
# std               2.853733      1.078730       0.463753         2.858881
# min            1970.000000   2021.000000       1.000000      1948.000000
# 25%            2019.000000   2022.000000       1.000000      2003.000000
# 50%            2020.000000   2023.000000       1.000000      2004.000000
# 75%            2022.000000   2023.000000       2.000000      2005.000000
# max            2025.000000   2024.000000       2.000000      2008.000000
#
#         CALIF_FINAL
# count  42492.000000
# mean       7.640941
# std        3.561482
# min        0.000000
# 25%        4.894000
# 50%        7.288000
# 75%       10.313000
# max       20.000000

# %%
df.head(5)
# Out:
#                                               IDHASH  \
# 0  E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1  2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2  3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3  FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4  E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
#
#                       COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0       LA DIVINA PROVIDENCIA         LIMA         LIMA
# 1           86019 LA LIBERTAD       ÁNCASH       HUARAZ
# 2  0113 DANIEL ALOMIAS ROBLES         LIMA         LIMA
# 3     SEBASTIAN SALAZAR BONDY         LIMA         LIMA
# 4           TRILCE LOS OLIVOS         LIMA         LIMA
#
#              COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0               SURQUILLO         PERÚ                 2020
# 1                  HUARAZ         PERÚ                 2017
# 2  SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3             SANTA ANITA         PERÚ                 2018
# 4    SAN MARTÍN DE PORRES         PERÚ                 2020
#
#                        ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0            INGENIERÍA DE SISTEMAS          2021              1  ...
# 1  INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 2               INGENIERÍA MECÁNICA          2021              1  ...
# 3            INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                      ARQUITECTURA          2021              1  ...
#
#            DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  NACIMIENTO_DEPA  \
# 0  SAN JUAN DE MIRAFLORES            2004            PERÚ             LIMA
# 1                  HUARAZ            2001            PERÚ           ÁNCASH
# 2  SAN JUAN DE LURIGANCHO            2000            PERÚ             LIMA
# 3             SANTA ANITA            2002            PERÚ             LIMA
# 4           INDEPENDENCIA            2004            PERÚ             LIMA
#
#   NACIMIENTO_PROV    NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  \
# 0            LIMA  VILLA EL SALVADOR  MASCULINO        3.11      NO
# 1          HUARAZ             HUARAZ   FEMENINO        3.58      NO
# 2            LIMA        JESÚS MARÍA  MASCULINO        8.04      NO
# 3            LIMA               LIMA  MASCULINO       10.82      NO
# 4            LIMA              COMAS   FEMENINO        6.21      NO
#
#                                            MODALIDAD
# 0  EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 1                                          ORDINARIO
# 2                                          ORDINARIO
# 3            EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                          ORDINARIO
#
# [5 rows x 22 columns]

# %% [markdown]
# <a class="anchor" id="desafio"></a>
#
# ### Desafíos comunes con archivos de datos.
#
# Recibir datos de terceros va a ser muy habitual en la labor de data scientists. Algunas situaciones a tener en cuenta (para el futuro), en particular con exceles y csvs, son las siguientes:
#
# Con CSV:
# - Problemas con los delimitadores: Lo común es  que el delimitador sea la coma `,`, sin embargo,`|`,  `;` ó incluso `Tab` pueden aparecer, lo que  originará errores de lectura si no se especifica el delimitador correcto.
# - Comillas que no cierran: `"""  ""`.
# - Codificación diferente:
#     - Datos en español en una codificación anglosajona (e.g.) ocasionará caracteres extraños.
#     - Tipo de datos diferente (string en vez de numérico).
# - Datos faltantes: la falta de comas puede ocasionar errores en cargar los datos.
# - Saltos de línea no sistemáticos
#
# Con Excel:
# - Datos no tabulares: Exceles que no tienen datos tabulares pueden ocasionar errores de lectura. Pueden ser generados por colores, más de un valor por celda (tipo testamento en una sola celda), títulos o encabezados, fórmulas
# - Más de un valor por celda.
# - Fórmulas de excel.

# %% [markdown]
# <a class="anchor" id="trabajando"></a>
#
# ### Trabajando con datos

# %% [markdown]
# <a class="anchor" id="exploracion"></a>
#
#
# ### Exploración inicial
#
# Los siguientes son métodos/atributos de exploración que aplicamos sobre el dataframe mismo.
#
# | Método / Atributo         | Descripción                                                                                             |
# |-----------------|---------------------------------------------------------------------------------------------------------|
# | `head(n)`/`tail(n)` | Muestra las primeras/últimas n filas del DataFrame.
# | `describe()`    | Da estadísticas como el promedio, desviación estándar, mínimo y máximo de **columnas numéricas**. |
# | `info()`        | Nos ofrece información importante como los tipos de los atributos y sus valores nulos.     |
# | `dtypes`        | Da los tipos de datos del dataframe                                             |
# | `shape`         | Informa sobre la dimensión del dataframe en forma de tupla `(nfilas, ncolumnas)` |
# | `columns`         | Informa sobre el nombre de las columnas del dataframe. |

# %%
df.describe()

# %%
#df.describe()
#df.info()
#df.head()
#df.tail(4)

#df.dtypes
#df.shape
#df.columnns

# %% [markdown]
# Ahora exploraremos una columna en particular. Aquí se utilizará la exploración para una columna determinada (luego veremos que estas son Series).
#
# | Método          | Descripción                                                                                       |
# |-----------------|---------------------------------------------------------------------------------------------------|
# | `unique()`      | Da los valores únicos de la serie.                                                          |
# | `nunique()`     | Cuenta cuántos elementos únicos hay en la serie.                                                 |
# | `sort_values()` | Ordena la serie.         |
# | `value_counts()`| Da distribución de frecuencias de cada valor único de la serie.                                             |
#
#
# Para datos numéricos:
# `sum()`, `mean()`,  `min()`, `max()`, `mode()`, `median()` ,  `std()`

# %%
df['COLEGIO'].unique
# Out:
# <bound method Series.unique of 0             LA DIVINA PROVIDENCIA
# 1                 86019 LA LIBERTAD
# 2        0113 DANIEL ALOMIAS ROBLES
# 3           SEBASTIAN SALAZAR BONDY
# 4                 TRILCE LOS OLIVOS
#                     ...
# 42511             BARTOLOME HERRERA
# 42512               FE Y ALEGRIA 59
# 42513                      CIENCIAS
# 42514                    SAN CARLOS
# 42515               TRILCE SAN JUAN
# Name: COLEGIO, Length: 42516, dtype: object>

# %%
df['COLEGIO'].nunique()
# Out:
# 3970

# %%
df.columns
# Out:
# Index(['IDHASH', 'COLEGIO', 'COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_DIST',
#        'COLEGIO_PAIS', 'COLEGIO_ANIO_EGRESO', 'ESPECIALIDAD', 'ANIO_POSTULA',
#        'CICLO_POSTULA', 'DOMICILIO_DEPA', 'DOMICILIO_PROV', 'DOMICILIO_DIST',
#        'ANIO_NACIMIENTO', 'NACIMIENTO_PAIS', 'NACIMIENTO_DEPA',
#        'NACIMIENTO_PROV', 'NACIMIENTO_DIST', 'SEXO', 'CALIF_FINAL', 'INGRESO',
#        'MODALIDAD'],
#       dtype='object')

# %%
df['NACIMIENTO_PAIS'].value_counts()
# Out:
# NACIMIENTO_PAIS
# PERÚ             42285
# ARGENTINA           53
# VENEZUELA           44
# JAPÓN               22
# ITALIA              19
# EE.UU.              17
# CHILE               16
# ESPAÑA              16
# BRAZIL               9
# BOLIVIA              9
# COLOMBIA             6
# ECUADOR              4
# SUIZA                4
# KOREA                2
# GUATEMALA            2
# NO ESPECIFICA        2
# URUGUAY              1
# HONDURAS             1
# SIRIA                1
# PARAGUAY             1
# FRANCIA              1
# MÉXICO               1
# Name: count, dtype: int64

# %%
df['NACIMIENTO_DEPA'].value_counts(normalize = True)
# Out:
# NACIMIENTO_DEPA
# LIMA             0.678404
# CALLAO           0.056932
# JUNIN            0.025051
# JUNÍN            0.019521
# ICA              0.018268
# PUNO             0.018079
# AYACUCHO         0.018008
# CAJAMARCA        0.017039
# ANCASH           0.015881
# LAMBAYEQUE       0.015267
# ÁNCASH           0.014676
# CUSCO            0.010682
# HUANCAVELICA     0.009170
# HUANUCO          0.007822
# AMAZONAS         0.007681
# PASCO            0.007563
# LA LIBERTAD      0.007090
# PIURA            0.006830
# HUÁNUCO          0.006830
# APURIMAC         0.006759
# AREQUIPA         0.006546
# APURÍMAC         0.005625
# LORETO           0.003923
# SAN MARTIN       0.003261
# SAN MARTÍN       0.003238
# TACNA            0.003096
# UCAYALI          0.002600
# TUMBES           0.001607
# MADRE DE DIOS    0.001087
# MOQUEGUA         0.001016
# VENEZUELA        0.000213
# OTRO             0.000189
# ITALIA           0.000024
# ZURICH           0.000024
# Name: proportion, dtype: float64

# %% [markdown]
# Ejercicios:
# - Averigua cuáles son los 5 primeros departamentos en donde nacen los postulantes.
# - Cuenta cuántos hombres/mujeres postulan a la UNI.
# - Cuenta cuántos ingresan.
# Hint: value_counts()

# %%
df['INGRESO'].value_counts(normalize = True)
# Out:
# INGRESO
# NO    0.835803
# SI    0.164197
# Name: proportion, dtype: float64

# %%
df['ESPECIALIDAD'].value_counts()
# Out:
# ESPECIALIDAD
# INGENIERÍA CIVIL                                7608
# INGENIERÍA DE SISTEMAS                          6334
# ARQUITECTURA                                    4713
# INGENIERÍA MECATRÓNICA                          3701
# INGENIERÍA INDUSTRIAL                           3667
# INGENIERÍA DE MINAS                             1529
# INGENIERÍA ECONÓMICA                            1523
# INGENIERÍA ELECTRÓNICA                          1472
# INGENIERÍA MECÁNICA                             1412
# INGENIERÍA QUÍMICA                              1229
# INGENIERÍA AMBIENTAL                             973
# CIENCIA DE LA COMPUTACIÓN                        879
# INGENIERÍA ELÉCTRICA                             827
# INGENIERÍA DE TELECOMUNICACIONES                 817
# FÍSICA                                           640
# INGENIERÍA DE CIBERSEGURIDAD                     608
# INGENIERÍA GEOLÓGICA                             601
# INGENIERÍA MECÁNICA-ELÉCTRICA                    587
# INGENIERÍA DE SOFTWARE                           527
# INGENIERÍA ESTADÍSTICA                           452
# INGENIERÍA SANITARIA                             390
# MATEMÁTICA                                       303
# INGENIERÍA FÍSICA                                294
# INGENIERÍA PETROQUÍMICA                          272
# INGENIERÍA METALÚRGICA                           254
# INGENIERÍA NAVAL                                 222
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL     207
# QUÍMICA                                          157
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL             144
# INGENIERÍA TEXTIL                                119
# Name: count, dtype: int64

# %%
pd.crosstab(df['ESPECIALIDAD'], df['NACIMIENTO_PAIS'])
# Out:
# NACIMIENTO_PAIS                               ARGENTINA  BOLIVIA  BRAZIL  \
# ESPECIALIDAD
# ARQUITECTURA                                         11        1       3
# CIENCIA DE LA COMPUTACIÓN                             2        0       0
# FÍSICA                                                1        0       0
# INGENIERÍA AMBIENTAL                                  0        0       0
# INGENIERÍA CIVIL                                     10        1       0
# INGENIERÍA DE CIBERSEGURIDAD                          0        0       0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL          0        0       0
# INGENIERÍA DE MINAS                                   1        0       0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL                  0        0       0
# INGENIERÍA DE SISTEMAS                                8        1       3
# INGENIERÍA DE SOFTWARE                                0        0       0
# INGENIERÍA DE TELECOMUNICACIONES                      3        0       0
# INGENIERÍA ECONÓMICA                                  1        0       0
# INGENIERÍA ELECTRÓNICA                                2        0       0
# INGENIERÍA ELÉCTRICA                                  1        0       0
# INGENIERÍA ESTADÍSTICA                                1        0       0
# INGENIERÍA FÍSICA                                     0        0       0
# INGENIERÍA GEOLÓGICA                                  0        1       0
# INGENIERÍA INDUSTRIAL                                 7        1       0
# INGENIERÍA MECATRÓNICA                                2        2       2
# INGENIERÍA MECÁNICA                                   0        1       0
# INGENIERÍA MECÁNICA-ELÉCTRICA                         0        0       0
# INGENIERÍA METALÚRGICA                                0        0       0
# INGENIERÍA NAVAL                                      0        0       1
# INGENIERÍA PETROQUÍMICA                               0        0       0
# INGENIERÍA QUÍMICA                                    2        0       0
# INGENIERÍA SANITARIA                                  0        0       0
# INGENIERÍA TEXTIL                                     0        0       0
# MATEMÁTICA                                            0        1       0
# QUÍMICA                                               1        0       0
#
# NACIMIENTO_PAIS                               CHILE  COLOMBIA  ECUADOR  \
# ESPECIALIDAD
# ARQUITECTURA                                      1         1        0
# CIENCIA DE LA COMPUTACIÓN                         0         0        1
# FÍSICA                                            3         0        0
# INGENIERÍA AMBIENTAL                              1         0        0
# INGENIERÍA CIVIL                                  2         0        0
# INGENIERÍA DE CIBERSEGURIDAD                      0         0        0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL      0         0        0
# INGENIERÍA DE MINAS                               0         1        0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL              0         0        0
# INGENIERÍA DE SISTEMAS                            2         2        1
# INGENIERÍA DE SOFTWARE                            0         0        0
# INGENIERÍA DE TELECOMUNICACIONES                  0         0        0
# INGENIERÍA ECONÓMICA                              1         0        0
# INGENIERÍA ELECTRÓNICA                            0         0        0
# INGENIERÍA ELÉCTRICA                              0         0        0
# INGENIERÍA ESTADÍSTICA                            2         0        0
# INGENIERÍA FÍSICA                                 0         0        0
# INGENIERÍA GEOLÓGICA                              0         1        0
# INGENIERÍA INDUSTRIAL                             1         0        1
# INGENIERÍA MECATRÓNICA                            1         0        0
# INGENIERÍA MECÁNICA                               0         0        1
# INGENIERÍA MECÁNICA-ELÉCTRICA                     0         0        0
# INGENIERÍA METALÚRGICA                            0         0        0
# INGENIERÍA NAVAL                                  0         0        0
# INGENIERÍA PETROQUÍMICA                           0         0        0
# INGENIERÍA QUÍMICA                                1         1        0
# INGENIERÍA SANITARIA                              0         0        0
# INGENIERÍA TEXTIL                                 0         0        0
# MATEMÁTICA                                        1         0        0
# QUÍMICA                                           0         0        0
#
# NACIMIENTO_PAIS                               EE.UU.  ESPAÑA  FRANCIA  \
# ESPECIALIDAD
# ARQUITECTURA                                       1       4        0
# CIENCIA DE LA COMPUTACIÓN                          0       0        0
# FÍSICA                                             1       0        0
# INGENIERÍA AMBIENTAL                               0       0        0
# INGENIERÍA CIVIL                                   2       0        0
# INGENIERÍA DE CIBERSEGURIDAD                       0       1        0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL       0       1        0
# INGENIERÍA DE MINAS                                0       2        0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL               1       0        0
# INGENIERÍA DE SISTEMAS                             3       2        0
# INGENIERÍA DE SOFTWARE                             2       0        0
# INGENIERÍA DE TELECOMUNICACIONES                   0       0        0
# INGENIERÍA ECONÓMICA                               0       0        0
# INGENIERÍA ELECTRÓNICA                             1       1        0
# INGENIERÍA ELÉCTRICA                               0       0        0
# INGENIERÍA ESTADÍSTICA                             0       0        0
# INGENIERÍA FÍSICA                                  0       0        0
# INGENIERÍA GEOLÓGICA                               0       0        0
# INGENIERÍA INDUSTRIAL                              3       3        0
# INGENIERÍA MECATRÓNICA                             0       1        0
# INGENIERÍA MECÁNICA                                1       0        1
# INGENIERÍA MECÁNICA-ELÉCTRICA                      0       0        0
# INGENIERÍA METALÚRGICA                             0       0        0
# INGENIERÍA NAVAL                                   0       0        0
# INGENIERÍA PETROQUÍMICA                            0       0        0
# INGENIERÍA QUÍMICA                                 0       0        0
# INGENIERÍA SANITARIA                               0       0        0
# INGENIERÍA TEXTIL                                  0       0        0
# MATEMÁTICA                                         2       1        0
# QUÍMICA                                            0       0        0
#
# NACIMIENTO_PAIS                               GUATEMALA  ...  JAPÓN  KOREA  \
# ESPECIALIDAD                                             ...
# ARQUITECTURA                                          0  ...      1      0
# CIENCIA DE LA COMPUTACIÓN                             0  ...      1      0
# FÍSICA                                                0  ...      0      0
# INGENIERÍA AMBIENTAL                                  0  ...      0      0
# INGENIERÍA CIVIL                                      0  ...      3      0
# INGENIERÍA DE CIBERSEGURIDAD                          0  ...      1      0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL          0  ...      0      0
# INGENIERÍA DE MINAS                                   0  ...      0      0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL                  0  ...      0      0
# INGENIERÍA DE SISTEMAS                                2  ...      9      0
# INGENIERÍA DE SOFTWARE                                0  ...      0      0
# INGENIERÍA DE TELECOMUNICACIONES                      0  ...      0      0
# INGENIERÍA ECONÓMICA                                  0  ...      0      2
# INGENIERÍA ELECTRÓNICA                                0  ...      1      0
# INGENIERÍA ELÉCTRICA                                  0  ...      0      0
# INGENIERÍA ESTADÍSTICA                                0  ...      0      0
# INGENIERÍA FÍSICA                                     0  ...      1      0
# INGENIERÍA GEOLÓGICA                                  0  ...      0      0
# INGENIERÍA INDUSTRIAL                                 0  ...      0      0
# INGENIERÍA MECATRÓNICA                                0  ...      1      0
# INGENIERÍA MECÁNICA                                   0  ...      1      0
# INGENIERÍA MECÁNICA-ELÉCTRICA                         0  ...      0      0
# INGENIERÍA METALÚRGICA                                0  ...      0      0
# INGENIERÍA NAVAL                                      0  ...      0      0
# INGENIERÍA PETROQUÍMICA                               0  ...      0      0
# INGENIERÍA QUÍMICA                                    0  ...      1      0
# INGENIERÍA SANITARIA                                  0  ...      0      0
# INGENIERÍA TEXTIL                                     0  ...      0      0
# MATEMÁTICA                                            0  ...      2      0
# QUÍMICA                                               0  ...      0      0
#
# NACIMIENTO_PAIS                               MÉXICO  NO ESPECIFICA  PARAGUAY  \
# ESPECIALIDAD
# ARQUITECTURA                                       0              0         0
# CIENCIA DE LA COMPUTACIÓN                          0              0         0
# FÍSICA                                             0              0         0
# INGENIERÍA AMBIENTAL                               0              0         0
# INGENIERÍA CIVIL                                   0              0         0
# INGENIERÍA DE CIBERSEGURIDAD                       0              0         0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL       0              0         0
# INGENIERÍA DE MINAS                                0              0         0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL               0              0         0
# INGENIERÍA DE SISTEMAS                             0              0         1
# INGENIERÍA DE SOFTWARE                             0              0         0
# INGENIERÍA DE TELECOMUNICACIONES                   0              0         0
# INGENIERÍA ECONÓMICA                               0              0         0
# INGENIERÍA ELECTRÓNICA                             0              0         0
# INGENIERÍA ELÉCTRICA                               0              2         0
# INGENIERÍA ESTADÍSTICA                             0              0         0
# INGENIERÍA FÍSICA                                  0              0         0
# INGENIERÍA GEOLÓGICA                               0              0         0
# INGENIERÍA INDUSTRIAL                              1              0         0
# INGENIERÍA MECATRÓNICA                             0              0         0
# INGENIERÍA MECÁNICA                                0              0         0
# INGENIERÍA MECÁNICA-ELÉCTRICA                      0              0         0
# INGENIERÍA METALÚRGICA                             0              0         0
# INGENIERÍA NAVAL                                   0              0         0
# INGENIERÍA PETROQUÍMICA                            0              0         0
# INGENIERÍA QUÍMICA                                 0              0         0
# INGENIERÍA SANITARIA                               0              0         0
# INGENIERÍA TEXTIL                                  0              0         0
# MATEMÁTICA                                         0              0         0
# QUÍMICA                                            0              0         0
#
# NACIMIENTO_PAIS                               PERÚ  SIRIA  SUIZA  URUGUAY  \
# ESPECIALIDAD
# ARQUITECTURA                                  4681      0      0        1
# CIENCIA DE LA COMPUTACIÓN                      869      1      1        0
# FÍSICA                                         632      0      0        0
# INGENIERÍA AMBIENTAL                           971      0      0        0
# INGENIERÍA CIVIL                              7586      0      0        0
# INGENIERÍA DE CIBERSEGURIDAD                   605      0      0        0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL   206      0      0        0
# INGENIERÍA DE MINAS                           1521      0      3        0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL           142      0      0        0
# INGENIERÍA DE SISTEMAS                        6287      0      0        0
# INGENIERÍA DE SOFTWARE                         524      0      0        0
# INGENIERÍA DE TELECOMUNICACIONES               813      0      0        0
# INGENIERÍA ECONÓMICA                          1516      0      0        0
# INGENIERÍA ELECTRÓNICA                        1466      0      0        0
# INGENIERÍA ELÉCTRICA                           823      0      0        0
# INGENIERÍA ESTADÍSTICA                         449      0      0        0
# INGENIERÍA FÍSICA                              293      0      0        0
# INGENIERÍA GEOLÓGICA                           598      0      0        0
# INGENIERÍA INDUSTRIAL                         3648      0      0        0
# INGENIERÍA MECATRÓNICA                        3682      0      0        0
# INGENIERÍA MECÁNICA                           1403      0      0        0
# INGENIERÍA MECÁNICA-ELÉCTRICA                  586      0      0        0
# INGENIERÍA METALÚRGICA                         254      0      0        0
# INGENIERÍA NAVAL                               221      0      0        0
# INGENIERÍA PETROQUÍMICA                        272      0      0        0
# INGENIERÍA QUÍMICA                            1221      0      0        0
# INGENIERÍA SANITARIA                           390      0      0        0
# INGENIERÍA TEXTIL                              119      0      0        0
# MATEMÁTICA                                     296      0      0        0
# QUÍMICA                                        156      0      0        0
#
# NACIMIENTO_PAIS                               VENEZUELA
# ESPECIALIDAD
# ARQUITECTURA                                          6
# CIENCIA DE LA COMPUTACIÓN                             4
# FÍSICA                                                3
# INGENIERÍA AMBIENTAL                                  1
# INGENIERÍA CIVIL                                      3
# INGENIERÍA DE CIBERSEGURIDAD                          1
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL          0
# INGENIERÍA DE MINAS                                   1
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL                  1
# INGENIERÍA DE SISTEMAS                                6
# INGENIERÍA DE SOFTWARE                                1
# INGENIERÍA DE TELECOMUNICACIONES                      1
# INGENIERÍA ECONÓMICA                                  2
# INGENIERÍA ELECTRÓNICA                                1
# INGENIERÍA ELÉCTRICA                                  1
# INGENIERÍA ESTADÍSTICA                                0
# INGENIERÍA FÍSICA                                     0
# INGENIERÍA GEOLÓGICA                                  1
# INGENIERÍA INDUSTRIAL                                 2
# INGENIERÍA MECATRÓNICA                                6
# INGENIERÍA MECÁNICA                                   2
# INGENIERÍA MECÁNICA-ELÉCTRICA                         0
# INGENIERÍA METALÚRGICA                                0
# INGENIERÍA NAVAL                                      0
# INGENIERÍA PETROQUÍMICA                               0
# INGENIERÍA QUÍMICA                                    1
# INGENIERÍA SANITARIA                                  0
# INGENIERÍA TEXTIL                                     0
# MATEMÁTICA                                            0
# QUÍMICA                                               0
#
# [30 rows x 22 columns]

# %% [markdown]
# <a class="anchor" id="select"></a>
#
# ### Cómo seleccionar datos
#
# A veces sólo necesitamos entender una parte de todos nuestros datos. Por ejemplo, queremos ver los datos de los partidos políticos:

# %%
# df['ANIO_NACIMIENTO'].unique()
# df['ANIO_NACIMIENTO'].nunique()
# df['NACIMIENTO_DEPA'].value_counts()
# df['NACIMIENTO_DEPA'].value_counts(normalize = True)

# %% [markdown]
# Un dataframe está compuesto de varias series: una columna es una serie diferente.

# %%
type(df['ANIO_NACIMIENTO']) # Forma de acceder a una columna.
# Otra forma:
# df.ANIO_NACIMIENTO # Mejor utilizar la anterior!

# Acceder a varias columnas:
df[['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']]

# %%
#### Explorando más de una columna:

# %%
pd.crosstab(df['NACIMIENTO_DEPA'], df['SEXO'])

# esta funcion nos permite hacer tablas cruzadas entre dos columnas.

pd.crosstab(df['NACIMIENTO_DEPA'], df['SEXO'])

# %% [markdown]
# ### Selección de datos

# %% [markdown]
# #### Selección de columnas

# %%
# por nombre:
peque_lst = ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']
peque_lst
#df[peque_lst]
# Out:
# ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']

# %%
df_small = df

# %%
df_small = df[peque_lst].copy()
df_small
# Out:
#        ANIO_NACIMIENTO NACIMIENTO_DEPA
# 0                 2004            LIMA
# 1                 2001          ÁNCASH
# 2                 2000            LIMA
# 3                 2002            LIMA
# 4                 2004            LIMA
# ...                ...             ...
# 42511             2002          CALLAO
# 42512             2004          CALLAO
# 42513             2006        AYACUCHO
# 42514             2004            LIMA
# 42515             2005            LIMA
#
# [42516 rows x 2 columns]

# %% [markdown]
# #### Selección y filtración de filas/columnas con ``` iloc``` y ```loc ```
#
# Primero seleccionaremos columnas, para lo que utilizaremos  ``` iloc``` y ```loc ```.

# %% [markdown]
# ##### Utilizando el iloc
# El iloc ubica las observaciones que corresponden al índice que le indicamos.
# Recordando nuestra base de postulantes:

# %%
# Agarrando observaciones puntuales

df.iloc[3]
# Out:
# IDHASH                 FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# COLEGIO                                          SEBASTIAN SALAZAR BONDY
# COLEGIO_DEPA                                                        LIMA
# COLEGIO_PROV                                                        LIMA
# COLEGIO_DIST                                                 SANTA ANITA
# COLEGIO_PAIS                                                        PERÚ
# COLEGIO_ANIO_EGRESO                                                 2018
# ESPECIALIDAD                                      INGENIERÍA ELECTRÓNICA
# ANIO_POSTULA                                                        2021
# CICLO_POSTULA                                                          1
# DOMICILIO_DEPA                                                      LIMA
# DOMICILIO_PROV                                                      LIMA
# DOMICILIO_DIST                                               SANTA ANITA
# ANIO_NACIMIENTO                                                     2002
# NACIMIENTO_PAIS                                                     PERÚ
# NACIMIENTO_DEPA                                                     LIMA
# NACIMIENTO_PROV                                                     LIMA
# NACIMIENTO_DIST                                                     LIMA
# SEXO                                                           MASCULINO
# CALIF_FINAL                                                        10.82
# INGRESO                                                               NO
# MODALIDAD                        EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# Name: 3, dtype: object

# %%
#nos estamos refiriendo a observaciones con números
df.iloc[[0, 4, 10]]
# Out:
#                                                IDHASH  \
# 0   E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 4   E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 10  93F72E732F5231CA28EF38661D5142CBEA7DCB92795B4D...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0            LA DIVINA PROVIDENCIA         LIMA         LIMA
# 4                TRILCE LOS OLIVOS         LIMA         LIMA
# 10  2095 HERNAN BUSSE DE LA GUERRA         LIMA         LIMA
#
#             COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0              SURQUILLO         PERÚ                 2020
# 4   SAN MARTÍN DE PORRES         PERÚ                 2020
# 10            LOS OLIVOS         PERÚ                 2018
#
#               ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0   INGENIERÍA DE SISTEMAS          2021              1  ...
# 4             ARQUITECTURA          2021              1  ...
# 10        INGENIERÍA NAVAL          2021              1  ...
#
#             DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  NACIMIENTO_DEPA  \
# 0   SAN JUAN DE MIRAFLORES            2004            PERÚ             LIMA
# 4            INDEPENDENCIA            2004            PERÚ             LIMA
# 10                EL TAMBO            2002            PERÚ            JUNÍN
#
#    NACIMIENTO_PROV    NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  \
# 0             LIMA  VILLA EL SALVADOR  MASCULINO        3.11      NO
# 4             LIMA              COMAS   FEMENINO        6.21      NO
# 10        HUANCAYO           EL TAMBO  MASCULINO        7.45      NO
#
#                                             MODALIDAD
# 0   EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 4                                           ORDINARIO
# 10                                          ORDINARIO
#
# [3 rows x 22 columns]

# %%
# Agarrando observaciones puntuales definidas por su indice
rows = [1, 2, 10,13,3000] #estamos definiendo filas
df.iloc[rows]
# Out:
#                                                  IDHASH  \
# 1     2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2     3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 10    93F72E732F5231CA28EF38661D5142CBEA7DCB92795B4D...
# 13    44940F569609FF5B23996C0A6AB82361FAD6C16B1C444A...
# 3000  D0B6404FF13C22B9EEBC0A0A9C6117C30A0A6062A2DF5A...
#
#                              COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 1                  86019 LA LIBERTAD       ÁNCASH       HUARAZ
# 2         0113 DANIEL ALOMIAS ROBLES         LIMA         LIMA
# 10    2095 HERNAN BUSSE DE LA GUERRA         LIMA         LIMA
# 13                 PROLOG DE CHINCHA          ICA      CHINCHA
# 3000            SAN JOSE DE NAZARETH         LIMA         LIMA
#
#                 COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 1                     HUARAZ         PERÚ                 2017
# 2     SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 10                LOS OLIVOS         PERÚ                 2018
# 13              CHINCHA ALTA         PERÚ                 2019
# 3000           PUENTE PIEDRA          NaN                 2022
#
#                           ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 1     INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 2                  INGENIERÍA MECÁNICA          2021              1  ...
# 10                    INGENIERÍA NAVAL          2021              1  ...
# 13                    INGENIERÍA CIVIL          2021              1  ...
# 3000            INGENIERÍA DE SISTEMAS          2023              2  ...
#
#               DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  NACIMIENTO_DEPA  \
# 1                     HUARAZ            2001            PERÚ           ÁNCASH
# 2     SAN JUAN DE LURIGANCHO            2000            PERÚ             LIMA
# 10                  EL TAMBO            2002            PERÚ            JUNÍN
# 13              GROCIO PRADO            2002            PERÚ              ICA
# 3000           PUENTE PIEDRA            2006            PERÚ             LIMA
#
#      NACIMIENTO_PROV         NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  \
# 1             HUARAZ                  HUARAZ   FEMENINO       3.580      NO
# 2               LIMA             JESÚS MARÍA  MASCULINO       8.040      NO
# 10          HUANCAYO                EL TAMBO  MASCULINO       7.450      NO
# 13           CHINCHA            CHINCHA ALTA  MASCULINO       6.430      NO
# 3000            LIMA  SAN JUAN DE LURIGANCHO   FEMENINO       5.773      NO
#
#                                     MODALIDAD
# 1                                   ORDINARIO
# 2                                   ORDINARIO
# 10                                  ORDINARIO
# 13    EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 3000    EXTRAORDINARIO - DOS PRIMEROS ALUMNOS
#
# [5 rows x 22 columns]

# %%
rows = [10,13, 2]
cols = [2,4,6]
df.iloc[rows, cols]
# Out:
#    COLEGIO_DEPA            COLEGIO_DIST  COLEGIO_ANIO_EGRESO
# 10         LIMA              LOS OLIVOS                 2018
# 13          ICA            CHINCHA ALTA                 2019
# 2          LIMA  SAN JUAN DE LURIGANCHO                 2016

# %%
df.iloc[3:, [4]]

# %%
# qué pasa si  hago...
#df.iloc[rows, ['COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_ANIO_EGRESO']]

# %%
df.iloc[:3,:3]

# %% [markdown]
# ##### Utilizando el ```loc```
#
# El ``` loc``` es una forma de ubicar observaciones que se basa en las etiquetas, tanto de columnas como de filas.

# %%
columnas = ['COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_ANIO_EGRESO']
filas = range(0,6)
df.loc[filas, columnas]
# Out:
#   COLEGIO_DEPA COLEGIO_PROV  COLEGIO_ANIO_EGRESO
# 0         LIMA         LIMA                 2020
# 1       ÁNCASH       HUARAZ                 2017
# 2         LIMA         LIMA                 2016
# 3         LIMA         LIMA                 2018
# 4         LIMA         LIMA                 2020
# 5    VENEZUELA    VENEZUELA                 2017

# %%
df2 = df.set_index('IDHASH')
#nos da el nombre y el dni del postulante. Si hay IDHASH repetidos, te indica las veces que ha postulado.
# Es este caso permite anonimizar los datos de nombre y DNI de los postulantes

# %%
df2.loc['E4287C2FE19F63C5E6641955147E36684A5A2FF8064676B6CB00A57522FD99A8175BC39CB2924C9F4D3848443267048FE4CB946A191592F9053A3D1705456A26']
# resultado de pasar toda una fila a través de una función que identifcique únicamente esa fila
# las funciones Hash pasan y transforma información para COMPACTARLA y anonimizarla
#USO DE HASH = Bioseguridad y contraseñas.
#Ej.: tienes una base de datos de contraseñas, pero si lo transformas con hash las vas a tener de forma anónima y deconstrida.
# Out:
# COLEGIO                                            LA DIVINA PROVIDENCIA
# COLEGIO_DEPA                                                        LIMA
# COLEGIO_PROV                                                        LIMA
# COLEGIO_DIST                                                   SURQUILLO
# COLEGIO_PAIS                                                        PERÚ
# COLEGIO_ANIO_EGRESO                                                 2020
# ESPECIALIDAD                                      INGENIERÍA DE SISTEMAS
# ANIO_POSTULA                                                        2021
# CICLO_POSTULA                                                          1
# DOMICILIO_DEPA                                                      LIMA
# DOMICILIO_PROV                                                      LIMA
# DOMICILIO_DIST                                    SAN JUAN DE MIRAFLORES
# ANIO_NACIMIENTO                                                     2004
# NACIMIENTO_PAIS                                                     PERÚ
# NACIMIENTO_DEPA                                                     LIMA
# NACIMIENTO_PROV                                                     LIMA
# NACIMIENTO_DIST                                        VILLA EL SALVADOR
# SEXO                                                           MASCULINO
# CALIF_FINAL                                                         3.11
# INGRESO                                                               NO
# MODALIDAD              EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# Name: E4287C2FE19F63C5E6641955147E36684A5A2FF8064676B6CB00A57522FD99A8175BC39CB2924C9F4D3848443267048FE4CB946A191592F9053A3D1705456A26, dtype: object

# %%
df.loc[:, columnas]

#  Con .iloc y .loc, hemos visto nuevas formas de acceder a las filas/columnas de un dataframe:
# df.loc[:, ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']]
# df.loc[1:3, ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']]
# df.iloc[:, [1, 2]]
# df.iloc[1:3, 2:4]
# Out:
#       COLEGIO_DEPA           COLEGIO_PROV  COLEGIO_ANIO_EGRESO
# 0             LIMA                   LIMA                 2020
# 1           ÁNCASH                 HUARAZ                 2017
# 2             LIMA                   LIMA                 2016
# 3             LIMA                   LIMA                 2018
# 4             LIMA                   LIMA                 2020
# ...            ...                    ...                  ...
# 42511         LIMA                   LIMA                 2019
# 42512       CALLAO  PROV CONST DEL CALLAO                 2021
# 42513     AYACUCHO               HUAMANGA                 2022
# 42514         LIMA                   LIMA                 2021
# 42515         LIMA                   LIMA                 2021
#
# [42516 rows x 3 columns]

# %% [markdown]
# <a class="anchor" id="filter"></a>
#
# ### Filtrando información
#
# Muchas veces querremos quedarnos con un subconjunto de datos que cumplen cierta condición. Las condiciones tienen que evaluarse a un booleano.

# %%
5 < 10
df[df['NACIMIENTO_PAIS'] == 'PERU'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #### Filtrando información con condiciones

# %%
# Podemos guardar las condiciones como variables y luego hacer el filtro.

condicion = [True]*(len(df) - 5) + [False] * (5) # Tenemos una lista de booleanons de la longitud del dataframe.
#df[condicion] # Filtramos el dataframe con la condición.

# %%
cond = df['COLEGIO_DEPA'] == 'LIMA'
# explora qué bota el cond.

df[cond]
df[cond].reset_index(drop = True) # drop = True sirve para q no se quede ennuewtro  dataframe
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 2      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 3      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 4      740625EEB5D80EFBCAA4E16DC690BA65594321F2EFE666...
# ...                                                  ...
# 31963  CDB1535A398BA8A4465DD7C10578DE7F6835513112F9D5...
# 31964  B72BBA63F1DD27BB1619F02203A83B65CF8C139797E800...
# 31965  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 31966  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 31967  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0            LA DIVINA PROVIDENCIA         LIMA         LIMA
# 1       0113 DANIEL ALOMIAS ROBLES         LIMA         LIMA
# 2          SEBASTIAN SALAZAR BONDY         LIMA         LIMA
# 3                TRILCE LOS OLIVOS         LIMA         LIMA
# 4      NUESTRA SEÑORA DE LA MERCED         LIMA         LIMA
# ...                            ...          ...          ...
# 31963            TRILCE LOS OLIVOS         LIMA         LIMA
# 31964               INNOVA SCHOOLS         LIMA         LIMA
# 31965            BARTOLOME HERRERA         LIMA         LIMA
# 31966                   SAN CARLOS         LIMA         LIMA
# 31967              TRILCE SAN JUAN         LIMA         LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 1      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 2                 SANTA ANITA         PERÚ                 2018
# 3        SAN MARTÍN DE PORRES         PERÚ                 2020
# 4           VILLA EL SALVADOR         PERÚ                 2019
# ...                       ...          ...                  ...
# 31963    SAN MARTIN DE PORRES          NaN                 2021
# 31964  SAN JUAN DE MIRAFLORES          NaN                 2019
# 31965              SAN MIGUEL          NaN                 2019
# 31966              LURIGANCHO          NaN                 2021
# 31967  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                  ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0      INGENIERÍA DE SISTEMAS          2021              1  ...
# 1         INGENIERÍA MECÁNICA          2021              1  ...
# 2      INGENIERÍA ELECTRÓNICA          2021              1  ...
# 3                ARQUITECTURA          2021              1  ...
# 4            INGENIERÍA CIVIL          2021              1  ...
# ...                       ...           ...            ...  ...
# 31963  INGENIERÍA DE SISTEMAS          2023              1  ...
# 31964  INGENIERÍA DE SISTEMAS          2023              1  ...
# 31965        INGENIERÍA CIVIL          2023              1  ...
# 31966            ARQUITECTURA          2023              1  ...
# 31967  INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                 DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0       SAN JUAN DE MIRAFLORES            2004            PERÚ
# 1       SAN JUAN DE LURIGANCHO            2000            PERÚ
# 2                  SANTA ANITA            2002            PERÚ
# 3                INDEPENDENCIA            2004            PERÚ
# 4                         LIMA            2002            PERÚ
# ...                        ...             ...             ...
# 31963     SAN MARTIN DE PORRES            2005            PERÚ
# 31964  VILLA MARIA DEL TRIUNFO            2003            PERÚ
# 31965                 LA PERLA            2002            PERÚ
# 31966               LURIGANCHO            2004            PERÚ
# 31967   SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 1                 LIMA                   LIMA             JESÚS MARÍA
# 2                 LIMA                   LIMA                    LIMA
# 3                 LIMA                   LIMA                   COMAS
# 4                 LIMA                   LIMA                    LIMA
# ...                ...                    ...                     ...
# 31963             LIMA                   LIMA                   LINCE
# 31964             LIMA                   LIMA                    LIMA
# 31965           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 31966             LIMA                   LIMA              MIRAFLORES
# 31967             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 1      MASCULINO       8.040      NO
# 2      MASCULINO      10.820      NO
# 3       FEMENINO       6.210      NO
# 4      MASCULINO       4.450      NO
# ...          ...         ...     ...
# 31963  MASCULINO      16.075      SI
# 31964  MASCULINO       6.277      NO
# 31965  MASCULINO       5.906      NO
# 31966   FEMENINO       9.477      NO
# 31967  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 1                                              ORDINARIO
# 2                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 3                                              ORDINARIO
# 4                                              ORDINARIO
# ...                                                  ...
# 31963                                          ORDINARIO
# 31964                                          ORDINARIO
# 31965                                          ORDINARIO
# 31966                                          ORDINARIO
# 31967                                          ORDINARIO
#
# [31968 rows x 22 columns]

# %%
cond_1 = df['COLEGIO_DEPA'] == "LIMA"
cond_2 = df['INGRESO'] == "NO"

cond_filtrado_and = df[cond_1 & cond_2] ## Pregunta: por qué no usamos el and y or, como habíamos visto antes?

cond_filtrado_or = df[cond_1 | cond_2]  # EN VECTORIAL, no es and es & y no es or es | y no es not, sino ~
cond_filtrado_and
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 6      740625EEB5D80EFBCAA4E16DC690BA65594321F2EFE666...
# ...                                                  ...
# 42508  5E35AC40B02D7C8E47EA088641791B7010FCCDD958B948...
# 42510  B72BBA63F1DD27BB1619F02203A83B65CF8C139797E800...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0            LA DIVINA PROVIDENCIA         LIMA         LIMA
# 2       0113 DANIEL ALOMIAS ROBLES         LIMA         LIMA
# 3          SEBASTIAN SALAZAR BONDY         LIMA         LIMA
# 4                TRILCE LOS OLIVOS         LIMA         LIMA
# 6      NUESTRA SEÑORA DE LA MERCED         LIMA         LIMA
# ...                            ...          ...          ...
# 42508       1168 HEROES DEL CENEPA         LIMA         LIMA
# 42510               INNOVA SCHOOLS         LIMA         LIMA
# 42511            BARTOLOME HERRERA         LIMA         LIMA
# 42514                   SAN CARLOS         LIMA         LIMA
# 42515              TRILCE SAN JUAN         LIMA         LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# 6           VILLA EL SALVADOR         PERÚ                 2019
# ...                       ...          ...                  ...
# 42508                    LIMA          NaN                 2020
# 42510  SAN JUAN DE MIRAFLORES          NaN                 2019
# 42511              SAN MIGUEL          NaN                 2019
# 42514              LURIGANCHO          NaN                 2021
# 42515  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                     ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0         INGENIERÍA DE SISTEMAS          2021              1  ...
# 2            INGENIERÍA MECÁNICA          2021              1  ...
# 3         INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                   ARQUITECTURA          2021              1  ...
# 6               INGENIERÍA CIVIL          2021              1  ...
# ...                          ...           ...            ...  ...
# 42508  CIENCIA DE LA COMPUTACIÓN          2023              1  ...
# 42510     INGENIERÍA DE SISTEMAS          2023              1  ...
# 42511           INGENIERÍA CIVIL          2023              1  ...
# 42514               ARQUITECTURA          2023              1  ...
# 42515     INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                 DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0       SAN JUAN DE MIRAFLORES            2004            PERÚ
# 2       SAN JUAN DE LURIGANCHO            2000            PERÚ
# 3                  SANTA ANITA            2002            PERÚ
# 4                INDEPENDENCIA            2004            PERÚ
# 6                         LIMA            2002            PERÚ
# ...                        ...             ...             ...
# 42508              EL AGUSTINO            2004            PERÚ
# 42510  VILLA MARIA DEL TRIUNFO            2003            PERÚ
# 42511                 LA PERLA            2002            PERÚ
# 42514               LURIGANCHO            2004            PERÚ
# 42515   SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 2                 LIMA                   LIMA             JESÚS MARÍA
# 3                 LIMA                   LIMA                    LIMA
# 4                 LIMA                   LIMA                   COMAS
# 6                 LIMA                   LIMA                    LIMA
# ...                ...                    ...                     ...
# 42508             LIMA                   LIMA             LA VICTORIA
# 42510             LIMA                   LIMA                    LIMA
# 42511           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42514             LIMA                   LIMA              MIRAFLORES
# 42515             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# 6      MASCULINO       4.450      NO
# ...          ...         ...     ...
# 42508  MASCULINO       7.350      NO
# 42510  MASCULINO       6.277      NO
# 42511  MASCULINO       5.906      NO
# 42514   FEMENINO       9.477      NO
# 42515  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 2                                              ORDINARIO
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                              ORDINARIO
# 6                                              ORDINARIO
# ...                                                  ...
# 42508                                          ORDINARIO
# 42510                                          ORDINARIO
# 42511                                          ORDINARIO
# 42514                                          ORDINARIO
# 42515                                          ORDINARIO
#
# [26587 rows x 22 columns]

# %%
## equivalente a:
df[(
    df['COLEGIO_DEPA'] == "LIMA") & (df['INGRESO'] == "NO")] ## necesitamos cerrarlo en paréntesis.

df[(df['COLEGIO_DEPA'] == "LIMA") | (df['INGRESO'] == "NO")]

# Nota1: Si queremos hacer un filtro con más de una condición, necesitamos cerrar cada condición en paréntesis.
# Nota2: Podemos almacenar el resultado como una variable, que será un dataframe nuevo.
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# 2      0113 DANIEL ALOMIAS ROBLES         LIMA                   LIMA
# 3         SEBASTIAN SALAZAR BONDY         LIMA                   LIMA
# 4               TRILCE LOS OLIVOS         LIMA                   LIMA
# ...                           ...          ...                    ...
# 42511           BARTOLOME HERRERA         LIMA                   LIMA
# 42512             FE Y ALEGRIA 59       CALLAO  PROV CONST DEL CALLAO
# 42513                    CIENCIAS     AYACUCHO               HUAMANGA
# 42514                  SAN CARLOS         LIMA                   LIMA
# 42515             TRILCE SAN JUAN         LIMA                   LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 1                      HUARAZ         PERÚ                 2017
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# ...                       ...          ...                  ...
# 42511              SAN MIGUEL          NaN                 2019
# 42512              VENTANILLA          NaN                 2021
# 42513       SAN JUAN BAUTISTA          NaN                 2022
# 42514              LURIGANCHO          NaN                 2021
# 42515  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                            ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0                INGENIERÍA DE SISTEMAS          2021              1  ...
# 1      INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 2                   INGENIERÍA MECÁNICA          2021              1  ...
# 3                INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                          ARQUITECTURA          2021              1  ...
# ...                                 ...           ...            ...  ...
# 42511                  INGENIERÍA CIVIL          2023              1  ...
# 42512                  INGENIERÍA CIVIL          2023              1  ...
# 42513                      ARQUITECTURA          2023              1  ...
# 42514                      ARQUITECTURA          2023              1  ...
# 42515            INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0      SAN JUAN DE MIRAFLORES            2004            PERÚ
# 1                      HUARAZ            2001            PERÚ
# 2      SAN JUAN DE LURIGANCHO            2000            PERÚ
# 3                 SANTA ANITA            2002            PERÚ
# 4               INDEPENDENCIA            2004            PERÚ
# ...                       ...             ...             ...
# 42511                LA PERLA            2002            PERÚ
# 42512              VENTANILLA            2004            PERÚ
# 42513                AYACUCHO            2006            PERÚ
# 42514              LURIGANCHO            2004            PERÚ
# 42515  SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 1               ÁNCASH                 HUARAZ                  HUARAZ
# 2                 LIMA                   LIMA             JESÚS MARÍA
# 3                 LIMA                   LIMA                    LIMA
# 4                 LIMA                   LIMA                   COMAS
# ...                ...                    ...                     ...
# 42511           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42512           CALLAO  PROV CONST DEL CALLAO                  CALLAO
# 42513         AYACUCHO               HUAMANGA                AYACUCHO
# 42514             LIMA                   LIMA              MIRAFLORES
# 42515             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 1       FEMENINO       3.580      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# ...          ...         ...     ...
# 42511  MASCULINO       5.906      NO
# 42512   FEMENINO       2.621      NO
# 42513   FEMENINO       7.974      NO
# 42514   FEMENINO       9.477      NO
# 42515  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 1                                              ORDINARIO
# 2                                              ORDINARIO
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                              ORDINARIO
# ...                                                  ...
# 42511                                          ORDINARIO
# 42512                                          ORDINARIO
# 42513                                          ORDINARIO
# 42514                                          ORDINARIO
# 42515                                          ORDINARIO
#
# [40916 rows x 22 columns]

# %%
cond_1 = df['COLEGIO_DEPA'] == "LIMA"
cond_2 = df['INGRESO'] == "NO"

cond_filtrado_and = df[cond_1 & cond_2]

cond_filtrado_and

# %%
## Ejercicio: Filtra el dataframe para que solo te quedes con las observaciones que sean de Lima y que hayan ingresado.

# %%
#df.query('ANIO_POSTULA > 2020') QUERY funciona solo con VALORES NUMÉRICOS
df.query('ANIO_POSTULA > 2020')
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# 2      0113 DANIEL ALOMIAS ROBLES         LIMA                   LIMA
# 3         SEBASTIAN SALAZAR BONDY         LIMA                   LIMA
# 4               TRILCE LOS OLIVOS         LIMA                   LIMA
# ...                           ...          ...                    ...
# 42511           BARTOLOME HERRERA         LIMA                   LIMA
# 42512             FE Y ALEGRIA 59       CALLAO  PROV CONST DEL CALLAO
# 42513                    CIENCIAS     AYACUCHO               HUAMANGA
# 42514                  SAN CARLOS         LIMA                   LIMA
# 42515             TRILCE SAN JUAN         LIMA                   LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 1                      HUARAZ         PERÚ                 2017
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# ...                       ...          ...                  ...
# 42511              SAN MIGUEL          NaN                 2019
# 42512              VENTANILLA          NaN                 2021
# 42513       SAN JUAN BAUTISTA          NaN                 2022
# 42514              LURIGANCHO          NaN                 2021
# 42515  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                            ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0                INGENIERÍA DE SISTEMAS          2021              1  ...
# 1      INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 2                   INGENIERÍA MECÁNICA          2021              1  ...
# 3                INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                          ARQUITECTURA          2021              1  ...
# ...                                 ...           ...            ...  ...
# 42511                  INGENIERÍA CIVIL          2023              1  ...
# 42512                  INGENIERÍA CIVIL          2023              1  ...
# 42513                      ARQUITECTURA          2023              1  ...
# 42514                      ARQUITECTURA          2023              1  ...
# 42515            INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0      SAN JUAN DE MIRAFLORES            2004            PERÚ
# 1                      HUARAZ            2001            PERÚ
# 2      SAN JUAN DE LURIGANCHO            2000            PERÚ
# 3                 SANTA ANITA            2002            PERÚ
# 4               INDEPENDENCIA            2004            PERÚ
# ...                       ...             ...             ...
# 42511                LA PERLA            2002            PERÚ
# 42512              VENTANILLA            2004            PERÚ
# 42513                AYACUCHO            2006            PERÚ
# 42514              LURIGANCHO            2004            PERÚ
# 42515  SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 1               ÁNCASH                 HUARAZ                  HUARAZ
# 2                 LIMA                   LIMA             JESÚS MARÍA
# 3                 LIMA                   LIMA                    LIMA
# 4                 LIMA                   LIMA                   COMAS
# ...                ...                    ...                     ...
# 42511           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42512           CALLAO  PROV CONST DEL CALLAO                  CALLAO
# 42513         AYACUCHO               HUAMANGA                AYACUCHO
# 42514             LIMA                   LIMA              MIRAFLORES
# 42515             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 1       FEMENINO       3.580      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# ...          ...         ...     ...
# 42511  MASCULINO       5.906      NO
# 42512   FEMENINO       2.621      NO
# 42513   FEMENINO       7.974      NO
# 42514   FEMENINO       9.477      NO
# 42515  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 1                                              ORDINARIO
# 2                                              ORDINARIO
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                              ORDINARIO
# ...                                                  ...
# 42511                                          ORDINARIO
# 42512                                          ORDINARIO
# 42513                                          ORDINARIO
# 42514                                          ORDINARIO
# 42515                                          ORDINARIO
#
# [42516 rows x 22 columns]

# %%
df[df['COLEGIO_DEPA'].isin(['LIMA', 'CALLAO'])]
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 6      740625EEB5D80EFBCAA4E16DC690BA65594321F2EFE666...
# ...                                                  ...
# 42510  B72BBA63F1DD27BB1619F02203A83B65CF8C139797E800...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                            COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0            LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 2       0113 DANIEL ALOMIAS ROBLES         LIMA                   LIMA
# 3          SEBASTIAN SALAZAR BONDY         LIMA                   LIMA
# 4                TRILCE LOS OLIVOS         LIMA                   LIMA
# 6      NUESTRA SEÑORA DE LA MERCED         LIMA                   LIMA
# ...                            ...          ...                    ...
# 42510               INNOVA SCHOOLS         LIMA                   LIMA
# 42511            BARTOLOME HERRERA         LIMA                   LIMA
# 42512              FE Y ALEGRIA 59       CALLAO  PROV CONST DEL CALLAO
# 42514                   SAN CARLOS         LIMA                   LIMA
# 42515              TRILCE SAN JUAN         LIMA                   LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# 6           VILLA EL SALVADOR         PERÚ                 2019
# ...                       ...          ...                  ...
# 42510  SAN JUAN DE MIRAFLORES          NaN                 2019
# 42511              SAN MIGUEL          NaN                 2019
# 42512              VENTANILLA          NaN                 2021
# 42514              LURIGANCHO          NaN                 2021
# 42515  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                  ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0      INGENIERÍA DE SISTEMAS          2021              1  ...
# 2         INGENIERÍA MECÁNICA          2021              1  ...
# 3      INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                ARQUITECTURA          2021              1  ...
# 6            INGENIERÍA CIVIL          2021              1  ...
# ...                       ...           ...            ...  ...
# 42510  INGENIERÍA DE SISTEMAS          2023              1  ...
# 42511        INGENIERÍA CIVIL          2023              1  ...
# 42512        INGENIERÍA CIVIL          2023              1  ...
# 42514            ARQUITECTURA          2023              1  ...
# 42515  INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                 DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0       SAN JUAN DE MIRAFLORES            2004            PERÚ
# 2       SAN JUAN DE LURIGANCHO            2000            PERÚ
# 3                  SANTA ANITA            2002            PERÚ
# 4                INDEPENDENCIA            2004            PERÚ
# 6                         LIMA            2002            PERÚ
# ...                        ...             ...             ...
# 42510  VILLA MARIA DEL TRIUNFO            2003            PERÚ
# 42511                 LA PERLA            2002            PERÚ
# 42512               VENTANILLA            2004            PERÚ
# 42514               LURIGANCHO            2004            PERÚ
# 42515   SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 2                 LIMA                   LIMA             JESÚS MARÍA
# 3                 LIMA                   LIMA                    LIMA
# 4                 LIMA                   LIMA                   COMAS
# 6                 LIMA                   LIMA                    LIMA
# ...                ...                    ...                     ...
# 42510             LIMA                   LIMA                    LIMA
# 42511           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42512           CALLAO  PROV CONST DEL CALLAO                  CALLAO
# 42514             LIMA                   LIMA              MIRAFLORES
# 42515             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# 6      MASCULINO       4.450      NO
# ...          ...         ...     ...
# 42510  MASCULINO       6.277      NO
# 42511  MASCULINO       5.906      NO
# 42512   FEMENINO       2.621      NO
# 42514   FEMENINO       9.477      NO
# 42515  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 2                                              ORDINARIO
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                              ORDINARIO
# 6                                              ORDINARIO
# ...                                                  ...
# 42510                                          ORDINARIO
# 42511                                          ORDINARIO
# 42512                                          ORDINARIO
# 42514                                          ORDINARIO
# 42515                                          ORDINARIO
#
# [33941 rows x 22 columns]

# %%
df[df['COLEGIO_DEPA'].isin(['LIMA', 'CALLAO'])]
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 6      740625EEB5D80EFBCAA4E16DC690BA65594321F2EFE666...
# ...                                                  ...
# 42510  B72BBA63F1DD27BB1619F02203A83B65CF8C139797E800...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                            COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0            LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 2       0113 DANIEL ALOMIAS ROBLES         LIMA                   LIMA
# 3          SEBASTIAN SALAZAR BONDY         LIMA                   LIMA
# 4                TRILCE LOS OLIVOS         LIMA                   LIMA
# 6      NUESTRA SEÑORA DE LA MERCED         LIMA                   LIMA
# ...                            ...          ...                    ...
# 42510               INNOVA SCHOOLS         LIMA                   LIMA
# 42511            BARTOLOME HERRERA         LIMA                   LIMA
# 42512              FE Y ALEGRIA 59       CALLAO  PROV CONST DEL CALLAO
# 42514                   SAN CARLOS         LIMA                   LIMA
# 42515              TRILCE SAN JUAN         LIMA                   LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# 6           VILLA EL SALVADOR         PERÚ                 2019
# ...                       ...          ...                  ...
# 42510  SAN JUAN DE MIRAFLORES          NaN                 2019
# 42511              SAN MIGUEL          NaN                 2019
# 42512              VENTANILLA          NaN                 2021
# 42514              LURIGANCHO          NaN                 2021
# 42515  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                  ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0      INGENIERÍA DE SISTEMAS          2021              1  ...
# 2         INGENIERÍA MECÁNICA          2021              1  ...
# 3      INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                ARQUITECTURA          2021              1  ...
# 6            INGENIERÍA CIVIL          2021              1  ...
# ...                       ...           ...            ...  ...
# 42510  INGENIERÍA DE SISTEMAS          2023              1  ...
# 42511        INGENIERÍA CIVIL          2023              1  ...
# 42512        INGENIERÍA CIVIL          2023              1  ...
# 42514            ARQUITECTURA          2023              1  ...
# 42515  INGENIERÍA DE SISTEMAS          2023              1  ...
#
#                 DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 0       SAN JUAN DE MIRAFLORES            2004            PERÚ
# 2       SAN JUAN DE LURIGANCHO            2000            PERÚ
# 3                  SANTA ANITA            2002            PERÚ
# 4                INDEPENDENCIA            2004            PERÚ
# 6                         LIMA            2002            PERÚ
# ...                        ...             ...             ...
# 42510  VILLA MARIA DEL TRIUNFO            2003            PERÚ
# 42511                 LA PERLA            2002            PERÚ
# 42512               VENTANILLA            2004            PERÚ
# 42514               LURIGANCHO            2004            PERÚ
# 42515   SAN JUAN DE LURIGANCHO            2005            PERÚ
#
#        NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                 LIMA                   LIMA       VILLA EL SALVADOR
# 2                 LIMA                   LIMA             JESÚS MARÍA
# 3                 LIMA                   LIMA                    LIMA
# 4                 LIMA                   LIMA                   COMAS
# 6                 LIMA                   LIMA                    LIMA
# ...                ...                    ...                     ...
# 42510             LIMA                   LIMA                    LIMA
# 42511           CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42512           CALLAO  PROV CONST DEL CALLAO                  CALLAO
# 42514             LIMA                   LIMA              MIRAFLORES
# 42515             LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# 6      MASCULINO       4.450      NO
# ...          ...         ...     ...
# 42510  MASCULINO       6.277      NO
# 42511  MASCULINO       5.906      NO
# 42512   FEMENINO       2.621      NO
# 42514   FEMENINO       9.477      NO
# 42515  MASCULINO       7.228      NO
#
#                                                MODALIDAD
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...
# 2                                              ORDINARIO
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 4                                              ORDINARIO
# 6                                              ORDINARIO
# ...                                                  ...
# 42510                                          ORDINARIO
# 42511                                          ORDINARIO
# 42512                                          ORDINARIO
# 42514                                          ORDINARIO
# 42515                                          ORDINARIO
#
# [33941 rows x 22 columns]

# %%
df[~df['COLEGIO_DEPA'].isin(['LIMA', 'CALLAO'])]
# Out:
#                                                   IDHASH  \
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 5      3A060265D9E508F256DC9E1881ED163F8D2FB192D04095...
# 9      6989381377E6B2A54A1AA295438E048B901748BD11501F...
# 13     44940F569609FF5B23996C0A6AB82361FAD6C16B1C444A...
# 15     1797D2A80BAB7378A3A88E4DAA2AD1EA14B7826EA2C088...
# ...                                                  ...
# 42479  37732DA979A3314D9684955270B1CB71DDCBF30DDE4179...
# 42490  BBC5813E727C3F221D06EC8B1C7B57AB73DC4CA235E435...
# 42494  1403BC8596CE6227F5D8D4B5562183F33009BCB52BDA74...
# 42505  C0911C32EDF8F44868F74266609F7634A38FB2F6101555...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
#
#                                 COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 1                     86019 LA LIBERTAD       ÁNCASH       HUARAZ
# 5      UNIDAD EDUCATIVA SAN JUDAS TADEO    VENEZUELA    VENEZUELA
# 9                         COAR AYACUCHO     AYACUCHO     HUAMANGA
# 13                    PROLOG DE CHINCHA          ICA      CHINCHA
# 15                 JOSE PARDO Y BARREDA          ICA      CHINCHA
# ...                                 ...          ...          ...
# 42479         FRANCISCO ANTONIO DE ZELA        TACNA        TACNA
# 42490                       SAN VICENTE          ICA          ICA
# 42494                        SANTA ROSA         PUNO         PUNO
# 42505                       JOSE GALVEZ         PUNO      YUNGUYO
# 42513                          CIENCIAS     AYACUCHO     HUAMANGA
#
#             COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 1                 HUARAZ         PERÚ                 2017
# 5              VENEZUELA    VENEZUELA                 2017
# 9               AYACUCHO         PERÚ                 2019
# 13          CHINCHA ALTA         PERÚ                 2019
# 15          CHINCHA ALTA          NaN                 2013
# ...                  ...          ...                  ...
# 42479              TACNA          NaN                 2022
# 42490                ICA          NaN                 2020
# 42494               PUNO          NaN                 2021
# 42505            YUNGUYO          NaN                 2018
# 42513  SAN JUAN BAUTISTA          NaN                 2022
#
#                            ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 1      INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 5         INGENIERÍA MECÁNICA-ELÉCTRICA          2021              1  ...
# 9                          ARQUITECTURA          2021              1  ...
# 13                     INGENIERÍA CIVIL          2021              1  ...
# 15               INGENIERÍA DE SISTEMAS          2024              1  ...
# ...                                 ...           ...            ...  ...
# 42479               INGENIERÍA DE MINAS          2023              1  ...
# 42490              INGENIERÍA ELÉCTRICA          2023              1  ...
# 42494              INGENIERÍA ECONÓMICA          2023              1  ...
# 42505             INGENIERÍA INDUSTRIAL          2023              1  ...
# 42513                      ARQUITECTURA          2023              1  ...
#
#                DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 1                      HUARAZ            2001            PERÚ
# 5           SANTIAGO DE SURCO            2000            PERÚ
# 9                    AYACUCHO            2003            PERÚ
# 13               GROCIO PRADO            2002            PERÚ
# 15     SAN JUAN DE LURIGANCHO            1997            PERÚ
# ...                       ...             ...             ...
# 42479              VENTANILLA            2005            PERÚ
# 42490       MAGDALENA DEL MAR            2003            PERÚ
# 42494                    PUNO            2005            PERÚ
# 42505             JESUS MARIA            2002            PERÚ
# 42513                AYACUCHO            2006            PERÚ
#
#        NACIMIENTO_DEPA NACIMIENTO_PROV NACIMIENTO_DIST       SEXO CALIF_FINAL  \
# 1               ÁNCASH          HUARAZ          HUARAZ   FEMENINO       3.580
# 5                JUNÍN     CHANCHAMAYO     CHANCHAMAYO  MASCULINO      10.530
# 9             AYACUCHO        HUAMANGA        AYACUCHO   FEMENINO       3.070
# 13                 ICA         CHINCHA    CHINCHA ALTA  MASCULINO       6.430
# 15                 ICA         CHINCHA    CHINCHA ALTA  MASCULINO       4.366
# ...                ...             ...             ...        ...         ...
# 42479      LA LIBERTAD       PACASMAYO       GUADALUPE   FEMENINO       2.790
# 42490              ICA             ICA             ICA  MASCULINO       0.000
# 42494             PUNO            PUNO            PUNO   FEMENINO       6.496
# 42505             PUNO         YUNGUYO         YUNGUYO  MASCULINO       8.682
# 42513         AYACUCHO        HUAMANGA        AYACUCHO   FEMENINO       7.974
#
#       INGRESO                                          MODALIDAD
# 1          NO                                          ORDINARIO
# 5          NO  EXTRAORDINARIO1 - CONVENIO ANDRES BELLO (inici...
# 9          NO                                          ORDINARIO
# 13         NO            EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE
# 15         NO                                          ORDINARIO
# ...       ...                                                ...
# 42479      NO                                          ORDINARIO
# 42490      NO                                          ORDINARIO
# 42494      NO                                          ORDINARIO
# 42505      NO                                          ORDINARIO
# 42513      NO                                          ORDINARIO
#
# [8575 rows x 22 columns]

# %% [markdown]
# En general, Pandas tiene una serie de métodos para filtrar información.
# Vamos viendo cuándo aplicar cada uno:
#
#
# | Método         | Ejemplo de uso                                                                                                        |
# |----------------|-----------------------------------------------------------------------------------------------------------------------|
# | `loc`          | `df.loc[(df['ANIO_POSTULA'] > 2020) & (df['ANIO_NACIMIENTO'] < 2000), 'ANIO_NACIMIENTO']`    |
# | `iloc`         | `df.iloc[0:5, 0:2]` Accede a las primeras 5 filas y primeras 2 columnas.                                                |
# | `query`        | `df.query('(ANIO_POSTULA > 2020) & (ANIO_NACIMIENTO < 2000)')`
# | `filter`       | `df.filter(items=['ANIO_NACIMIENTO', 'ANIO_POSTULA'])`                                          |
# | `where`        | `df.where((df['ANIO_POSTULA'] > 2020) & (df['ANIO_NACIMIENTO'] < 2000))` Preserva shape pero rellena con Nan     |
# | `mask`         | `df.mask((df['ANIO_POSTULA'] > 2020) & (df['ANIO_NACIMIENTO'] < 2000))` Cambia a NaN los valores donde 'ANIO_POSTULA' > 2020 y 'ANIO_NACIMIENTO' < 2000.                            |
# | `isin`         | `df[df['ANIO_NACIMIENTO'].isin([2000, 2001])]`

# %%
df.loc[
(df['ANIO_POSTULA'] > 2020
) & (
    df['ANIO_NACIMIENTO'] < 2000
), :]
# para situar observaciones qu ecumplan ciertas características
# Out:
#                                                   IDHASH  \
# 7      922382307F9D6F9F5BABC2C815528642B93E83527224EC...
# 15     1797D2A80BAB7378A3A88E4DAA2AD1EA14B7826EA2C088...
# 83     8B5EF615D131BA731AB3F0D9401708B798B780A4BE7BCD...
# 114    3A4C3DEB55F97A3E6CEE7C01650D4FD74C393F1732260E...
# 138    C72577E64EA58227B61673148CA343C7BEE561FB072310...
# ...                                                  ...
# 42408  87949A113B8ADF30820065058B2F4A77929E45D26B988A...
# 42421  702280F15AAD42C6B18030AC3465B3C0B7F16A56073B53...
# 42444  98A7693D745E4404E75FE930DBCA0F3AF7E15300214A90...
# 42449  42095898DC500CFC8ABDC3291485D2FE841C0BB3D2D9DC...
# 42464  85FC503AD939CFD0FC330E1CA320F3D1E8658A64DAA1B8...
#
#                                         COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 7                             NICOLAS COPERNICO         LIMA         LIMA
# 15                         JOSE PARDO Y BARREDA          ICA      CHINCHA
# 83     UNIVERSIDAD PRIVADA DEL NORTE SEDE BREÑA          NaN          NaN
# 114             POLITECNICO REGIONAL DEL CENTRO        JUNÍN     HUANCAYO
# 138          UNIVERSIDAD NACIONAL DE INGENIERÍA          NaN          NaN
# ...                                         ...          ...          ...
# 42408                               VON NEUMANN      HUANUCO      HUANUCO
# 42421    UNIVERSIDAD DE INGENIERIA Y TECNOLOGIA          NaN          NaN
# 42444                      UNIVERSIDAD DE PIURA          NaN          NaN
# 42449                           LUZ Y ESPERANZA         LIMA         LIMA
# 42464                            CLAUDIO GALENO         PUNO    SAN ROMAN
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 7      SAN JUAN DE LURIGANCHO         PERÚ                 2015
# 15               CHINCHA ALTA          NaN                 2013
# 83                        NaN          NaN                 2015
# 114                  EL TAMBO         PERÚ                 2016
# 138                       NaN          NaN                 2008
# ...                       ...          ...                  ...
# 42408                 HUANUCO          NaN                 2007
# 42421                     NaN          NaN                 2013
# 42444                     NaN          NaN                 2001
# 42449  SAN JUAN DE MIRAFLORES          NaN                 2013
# 42464                 JULIACA          NaN                 2015
#
#                     ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 7           INGENIERÍA AMBIENTAL          2021              1  ...
# 15        INGENIERÍA DE SISTEMAS          2024              1  ...
# 83                  ARQUITECTURA          2023              2  ...
# 114             INGENIERÍA NAVAL          2021              1  ...
# 138         INGENIERÍA ECONÓMICA          2023              2  ...
# ...                          ...           ...            ...  ...
# 42408  CIENCIA DE LA COMPUTACIÓN          2023              1  ...
# 42421       INGENIERÍA ELÉCTRICA          2023              1  ...
# 42444           INGENIERÍA CIVIL          2023              1  ...
# 42449         INGENIERÍA QUÍMICA          2023              1  ...
# 42464           INGENIERÍA CIVIL          2023              1  ...
#
#                DOMICILIO_DIST ANIO_NACIMIENTO NACIMIENTO_PAIS  \
# 7                        LIMA            1999            PERÚ
# 15     SAN JUAN DE LURIGANCHO            1997            PERÚ
# 83     SAN JUAN DE LURIGANCHO            1999            PERÚ
# 114                  HUANCAYO            1999            PERÚ
# 138                       ATE            1992            PERÚ
# ...                       ...             ...             ...
# 42408                 HUANUCO            1991            PERÚ
# 42421              CHORRILLOS            1997            PERÚ
# 42444               SAN BORJA            1985            PERÚ
# 42449  SAN JUAN DE MIRAFLORES            1996            PERÚ
# 42464                 JULIACA            1999            PERÚ
#
#        NACIMIENTO_DEPA NACIMIENTO_PROV         NACIMIENTO_DIST       SEXO  \
# 7                 LIMA            LIMA  SAN JUAN DE LURIGANCHO   FEMENINO
# 15                 ICA         CHINCHA            CHINCHA ALTA  MASCULINO
# 83                LIMA            LIMA  SAN JUAN DE LURIGANCHO   FEMENINO
# 114           APURÍMAC     ANDAHUAYLAS    SAN ANTONIO DE CACHI  MASCULINO
# 138               LIMA            LIMA                    LIMA  MASCULINO
# ...                ...             ...                     ...        ...
# 42408          HUANUCO         HUANUCO                 HUANUCO  MASCULINO
# 42421              ICA         CHINCHA            CHINCHA ALTA  MASCULINO
# 42444           TUMBES          TUMBES                  TUMBES  MASCULINO
# 42449             LIMA            LIMA  SAN JUAN DE MIRAFLORES   FEMENINO
# 42464             PUNO       SAN ROMAN                 JULIACA  MASCULINO
#
#       CALIF_FINAL INGRESO                                          MODALIDAD
# 7           5.970      NO                                          ORDINARIO
# 15          4.366      NO                                          ORDINARIO
# 83         11.064      NO                  EXTRAORDINARIO - TRASLADO EXTERNO
# 114         2.130      NO                                          ORDINARIO
# 138           NaN      SI         EXTRAORDINARIO - TITULADOS O GRADUADOS UNI
# ...           ...     ...                                                ...
# 42408      17.229      SI                                          ORDINARIO
# 42421       2.833      NO                  EXTRAORDINARIO - TRASLADO EXTERNO
# 42444       9.000      NO  EXTRAORDINARIO - TITULADOS O GRADUADOS EN OTRA...
# 42449       4.277      NO                                          ORDINARIO
# 42464      10.532      NO  EXTRAORDINARIO INGRESO DIRECTO CEPRE-UNI O CEP...
#
# [2128 rows x 22 columns]

# %% [markdown]
# ## Ejercicio:
# 1. Filtra el dataframe y quédate con quienes postularon a la 'ESPECIALIDAD' de INGENIERÍA MECATRÓNICA y cuyo lugar de nacimiento sea Callao.
# 2. Filtra el dataframe y quédate con los postulantes cuyo país de estudio no haya sido Perú.
# 3. Filtra el dataframe y quédate con los postulantes de nacieron en Cajamarca y sí ingresaron.
# 4. Filtra el dataframe y quédate con los postulantes que obtuvieron una calificación final mayor a 17 e ingresaron por modalidad ordinario.
